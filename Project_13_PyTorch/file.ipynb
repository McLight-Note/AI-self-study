# %%
import torch

# %%
data = [[1,2,3],
        [4,5,6]]
my_tensor = torch.tensor(data)
my_tensor
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
my_tensor.shape
# Out:
# torch.Size([2, 3])

# %%
my_tensor.dtype
# Out:
# torch.int64

# %%
a = my_tensor
b = torch.tensor([[2,2,5],
                  [3,3,2]])

# %%
a+b
# Out:
# tensor([[3, 4, 8],
#         [7, 8, 8]])

# %%
adjustment = torch.tensor([[2, 2, 2], [2, 2, 2]])

corrected_temperatures = adjustment + 2
print("Corrected temperatures:", corrected_temperatures)
# Out:
# Corrected temperatures: tensor([[4, 4, 4],
#         [4, 4, 4]])

# %%
import torch.nn as nn

# %%
input_tensor = torch.tensor(
    [[0.3471, 0.4547, -0.2356]]
)
linear_layer = nn.Linear(in_features=3,out_features=2)

# %%
output = linear_layer(input_tensor)
output
# Out:
# tensor([[-0.2886, -0.2004]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ![description](scher.png)

# %%
linear_layer.weight
# Out:
# Parameter containing:
# tensor([[ 0.4007,  0.0567, -0.0006],
#         [ 0.1393,  0.0049, -0.3107]], requires_grad=True)

# %%
linear_layer.bias
# Out:
# Parameter containing:
# tensor([-0.4537, -0.3242], requires_grad=True)

# %% [markdown]
# ![description](scher2.png)

# %%
model = nn.Sequential(
    nn.Linear(n_features, 8), # n_features represents number of input features
    nn.Linear(8,4),
    nn.Linear(4, n_classes) # n_classes represents number of output classes
)

# %%
model = nn.Sequential(
    nn.Linear(5, 8),
    nn.Linear(8,4),
    nn.Linear(4, 10)
)

# %%
model = nn.Sequential(
    nn.Linear(8,4),
    nn.Linear(4,2)
)
total = 0
for parameter in model.parameters():
    total += parameter.numel()
total
# Out:
# 46

# %% [markdown]
# ![description](scher3.png)

# %%
input_tensor = torch.tensor([[6]])
sigmoid = nn.Sigmoid()
output = sigmoid(input_tensor)
output
# Out:
# tensor([[0.9975]])

# %%
input_tensor = torch.tensor([[1.0, -6.0, 2.5, -0.3, 1.2, 0.8]])

softmax = nn.Softmax()
probabilities = softmax(input_tensor)
print(probabilities)
# Out:
# tensor([[1.2828e-01, 1.1698e-04, 5.7492e-01, 3.4961e-02, 1.5669e-01, 1.0503e-01]])
# /Users/mclight/Downloads/GitHub/AI_Self-Study/.conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1775: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
