# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Ice_Cream.csv')
df
# Out:
#              Revenue
# Temperature
# 24.6             535
# 26.1             626
# 27.8             661
# 20.6             488
# 11.6             317
# ...              ...
# 22.3             525
# 32.9             756
# 12.6             307
# 22.4             567
# 29.0             656
#
# [500 rows x 1 columns]

# %%
df.plot(kind='line', subplots = False, title='Ice Cream Ratings', xlabel='Daily Ratings', ylabel='Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
df.plot(kind='bar', stacked=True)
