# %%
import pandas as pd
import yfinance as yf
import math

df = yf.download("GOOGL", start="2010-01-01", end="2025-01-01", actions=True)

print(df.head())
# Out:
# /var/folders/0s/s2qqdkfs7_b9yv8pvrv2djp00000gn/T/ipykernel_14036/2233899527.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("GOOGL", start="2010-01-01", end="2025-01-01", actions=True)
# [*********************100%***********************]  1 of 1 completed
# Price           Close Dividends       High        Low       Open Stock Splits  \
# Ticker          GOOGL     GOOGL      GOOGL      GOOGL      GOOGL        GOOGL
# Date
# 2010-01-04  15.590930       0.0  15.659588  15.528493  15.595905          0.0
# 2010-01-05  15.522272       0.0  15.618045  15.461327  15.601626          0.0
# 2010-01-06  15.130977       0.0  15.568791  15.083713  15.568791          0.0
# 2010-01-07  14.778733       0.0  15.174260  14.742664  15.159334          0.0
# 2010-01-08  14.975752       0.0  15.006348  14.654604  14.726495          0.0
#
# Price          Volume
# Ticker          GOOGL
# Date
# 2010-01-04   78169752
# 2010-01-05  120067812
# 2010-01-06  158988852
# 2010-01-07  256315428
# 2010-01-08  188783028

# %%
print(df.columns)
# Out:
# MultiIndex([(       'Close', 'GOOGL'),
#             (   'Dividends', 'GOOGL'),
#             (        'High', 'GOOGL'),
#             (         'Low', 'GOOGL'),
#             (        'Open', 'GOOGL'),
#             ('Stock Splits', 'GOOGL'),
#             (      'Volume', 'GOOGL')],
#            names=['Price', 'Ticker'])

# %%
df.columns = [col[0] if isinstance(col, tuple) else col for col in df.columns]

# %%
print(df.columns)
# Out:
# Index(['Close', 'Dividends', 'High', 'Low', 'Open', 'Stock Splits', 'Volume'], dtype='object')

# %%
df = df[['Open', 'High', 'Low', 'Close', 'Volume']]

df['HL_PCT'] = (df['High'] - df['Close']) / df['Close'] * 100.0
df['PCT_change'] = (df['Close'] - df['Open']) / df['Open'] * 100.0

print(df.head())
# Out:
#                  Open       High        Low      Close     Volume    HL_PCT  \
# Date
# 2010-01-04  15.595905  15.659588  15.528493  15.590930   78169752  0.440372
# 2010-01-05  15.601626  15.618045  15.461327  15.522272  120067812  0.617000
# 2010-01-06  15.568791  15.568791  15.083713  15.130977  158988852  2.893498
# 2010-01-07  15.159334  15.174260  14.742664  14.778733  256315428  2.676322
# 2010-01-08  14.726495  15.006348  14.654604  14.975752  188783028  0.204306
#
#             PCT_change
# Date
# 2010-01-04   -0.031900
# 2010-01-05   -0.508628
# 2010-01-06   -2.812129
# 2010-01-07   -2.510668
# 2010-01-08    1.692573
# /var/folders/0s/s2qqdkfs7_b9yv8pvrv2djp00000gn/T/ipykernel_14036/3224691845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HL_PCT'] = (df['High'] - df['Close']) / df['Close'] * 100.0

# %%
df = df[['Open', 'High', 'Low', 'Close', 'Volume']]

df['HL_PCT'] = (df['High'] - df['Close']) / df['Close'] * 100.0
df['PCT_change'] = (df['Close'] - df['Open']) / df['Open'] * 100.0

print(df.head())
# Out:
#                  Open       High        Low      Close     Volume    HL_PCT  \
# Date
# 2010-01-04  15.595905  15.659588  15.528493  15.590930   78169752  0.440372
# 2010-01-05  15.601626  15.618045  15.461327  15.522272  120067812  0.617000
# 2010-01-06  15.568791  15.568791  15.083713  15.130977  158988852  2.893498
# 2010-01-07  15.159334  15.174260  14.742664  14.778733  256315428  2.676322
# 2010-01-08  14.726495  15.006348  14.654604  14.975752  188783028  0.204306
#
#             PCT_change
# Date
# 2010-01-04   -0.031900
# 2010-01-05   -0.508628
# 2010-01-06   -2.812129
# 2010-01-07   -2.510668
# 2010-01-08    1.692573

# %%
forecast_col = 'Close'
df.fillna(-99999,inplace=True)

forecast_out = int(math.ceil(0.01*len(df)))

df['label'] = df[forecast_col].shift(-forecast_out)

print(df.head())
# Out:
#                  Open       High        Low      Close     Volume    HL_PCT  \
# Date
# 2010-01-04  15.595905  15.659588  15.528493  15.590930   78169752  0.440372
# 2010-01-05  15.601626  15.618045  15.461327  15.522272  120067812  0.617000
# 2010-01-06  15.568791  15.568791  15.083713  15.130977  158988852  2.893498
# 2010-01-07  15.159334  15.174260  14.742664  14.778733  256315428  2.676322
# 2010-01-08  14.726495  15.006348  14.654604  14.975752  188783028  0.204306
#
#             PCT_change      label
# Date
# 2010-01-04   -0.031900  13.310313
# 2010-01-05   -0.508628  13.220761
# 2010-01-06   -2.812129  13.095387
# 2010-01-07   -2.510668  13.104589
# 2010-01-08    1.692573  13.251108

# %%
df.dropna(inplace=True)
print(df.tail())
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2023-05-05  104.195099  105.248778  103.489333  104.940628  26639300
# 2023-05-08  104.552962  107.316387  104.533084  107.127518  26511400
# 2023-05-09  107.743823  109.493333  106.550980  106.710022  36360100
# 2023-05-10  107.326330  112.266702  107.286567  111.083794  63153400
# 2023-05-11  114.712030  117.217004  113.727934  115.875053  78900000
#
#               HL_PCT  PCT_change       label
# Date
# 2023-05-05  0.293642    0.715512  117.634506
# 2023-05-08  0.176304    2.462442  117.624565
# 2023-05-09  2.608294   -0.959499  119.463539
# 2023-05-10  1.064879    3.500971  118.389977
# 2023-05-11  1.158101    1.013863  118.986389
