# %%
import pandas as pd
import yfinance as yf
import math
import numpy as np
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Download GOOGL data
df = yf.download("GOOGL", start="2010-01-01", end="2025-01-01", actions=True)

# Keep necessary columns
df = df[['Open', 'High', 'Low', 'Close', 'Volume']]

# Add percentage change columns
df['HL_PCT'] = (df['High'] - df['Close']) / df['Close'] * 100.0
df['PCT_change'] = (df['Close'] - df['Open']) / df['Open'] * 100.0

# Forecast setup
forecast_col = 'Close'
df.fillna(-99999, inplace=True)

forecast_out = int(math.ceil(0.01 * len(df)))
df['label'] = df[forecast_col].shift(-forecast_out)

# Drop NaNs after shift
df.dropna(inplace=True)

print(df.head())
print(df.tail())
# Out:
# /var/folders/0s/s2qqdkfs7_b9yv8pvrv2djp00000gn/T/ipykernel_23793/1804133752.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("GOOGL", start="2010-01-01", end="2025-01-01", actions=True)
# [*********************100%***********************]  1 of 1 completed
# Price            Open       High        Low      Close     Volume    HL_PCT  \
# Ticker          GOOGL      GOOGL      GOOGL      GOOGL      GOOGL
# Date
# 2010-01-04  15.595906  15.659589  15.528494  15.590931   78169752  0.440372
# 2010-01-05  15.601626  15.618045  15.461327  15.522272  120067812  0.617000
# 2010-01-06  15.568790  15.568790  15.083712  15.130976  158988852  2.893498
# 2010-01-07  15.159335  15.174261  14.742665  14.778734  256315428  2.676322
# 2010-01-08  14.726495  15.006348  14.654604  14.975752  188783028  0.204306
#
# Price      PCT_change      label
# Ticker
# Date
# 2010-01-04  -0.031900  13.251109
# 2010-01-05  -0.508628  13.459320
# 2010-01-06  -2.812129  13.565292
# 2010-01-07  -2.510668  13.795890
# 2010-01-08   1.692573  14.035195
# Price             Open        High         Low       Close    Volume  \
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL     GOOGL
# Date
# 2024-10-30  180.047564  181.382886  173.450741  173.849350  68890800
# 2024-10-31  172.524012  176.201098  170.401462  170.511078  44769000
# 2024-11-01  169.474729  171.716854  168.288892  170.690445  31796500
# 2024-11-04  169.335201  170.132404  167.421923  168.647629  21492700
# 2024-11-05  168.836962  169.933117  168.249030  169.145889  18242100
#
# Price         HL_PCT PCT_change       label
# Ticker
# Date
# 2024-10-30  4.333370  -3.442543  195.647552
# 2024-10-31  3.337039  -1.166756  195.138763
# 2024-11-01  0.601328   0.717343  192.305450
# 2024-11-04  0.880401  -0.406042  190.789032
# 2024-11-05  0.465414   0.182974  188.853622

# %%
x = np.array(df.drop(['label'],1))
y = np.array(df['label'])s

x = preprocessing.scale(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = np.array(df.drop(['label'],1))
#       2 y = np.array(df['label'])
#       4 x = preprocessing.scale(x)
#
# TypeError: DataFrame.drop() takes from 1 to 2 positional arguments but 3 were given
