# %%
import pandas as pd
import yfinance as yf

df = yf.download("GOOGL", start="2010-01-01", end="2025-01-01", actions=True)

print(df.head())
# Out:
# /var/folders/0s/s2qqdkfs7_b9yv8pvrv2djp00000gn/T/ipykernel_4437/688238605.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("GOOGL", start="2010-01-01", end="2025-01-01", actions=True)
# [*********************100%***********************]  1 of 1 completed
# Price           Close Dividends       High        Low       Open Stock Splits  \
# Ticker          GOOGL     GOOGL      GOOGL      GOOGL      GOOGL        GOOGL
# Date
# 2010-01-04  15.590930       0.0  15.659588  15.528493  15.595905          0.0
# 2010-01-05  15.522273       0.0  15.618046  15.461328  15.601627          0.0
# 2010-01-06  15.130976       0.0  15.568790  15.083712  15.568790          0.0
# 2010-01-07  14.778734       0.0  15.174261  14.742665  15.159335          0.0
# 2010-01-08  14.975752       0.0  15.006348  14.654604  14.726495          0.0
#
# Price          Volume
# Ticker          GOOGL
# Date
# 2010-01-04   78169752
# 2010-01-05  120067812
# 2010-01-06  158988852
# 2010-01-07  256315428
# 2010-01-08  188783028

# %%
print(df.columns)
# Out:
# MultiIndex([(       'Close', 'GOOGL'),
#             (   'Dividends', 'GOOGL'),
#             (        'High', 'GOOGL'),
#             (         'Low', 'GOOGL'),
#             (        'Open', 'GOOGL'),
#             ('Stock Splits', 'GOOGL'),
#             (      'Volume', 'GOOGL')],
#            names=['Price', 'Ticker'])

# %%
df.columns = [col[0] if isinstance(col, tuple) else col for col in df.columns]

# %%
print(df.columns)
# Out:
# Index(['Close', 'Dividends', 'High', 'Low', 'Open', 'Stock Splits', 'Volume'], dtype='object')

# %%
df = df[['Open', 'High', 'Low', 'Close', 'Volume']]

df['HL_PCT'] = (df['High'] - df['Close']) / df['Close'] * 100.0
df['PCT_change'] = (df['Close'] - df['Open']) / df['Open'] * 100.0

print(df.head())
# Out:
#                  Open       High        Low      Close     Volume    HL_PCT  \
# Date
# 2010-01-04  15.595905  15.659588  15.528493  15.590930   78169752  0.440372
# 2010-01-05  15.601627  15.618046  15.461328  15.522273  120067812  0.617000
# 2010-01-06  15.568790  15.568790  15.083712  15.130976  158988852  2.893498
# 2010-01-07  15.159335  15.174261  14.742665  14.778734  256315428  2.676322
# 2010-01-08  14.726495  15.006348  14.654604  14.975752  188783028  0.204306
#
#             PCT_change
# Date
# 2010-01-04   -0.031900
# 2010-01-05   -0.508628
# 2010-01-06   -2.812129
# 2010-01-07   -2.510668
# 2010-01-08    1.692573
# /var/folders/0s/s2qqdkfs7_b9yv8pvrv2djp00000gn/T/ipykernel_4437/3224691845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HL_PCT'] = (df['High'] - df['Close']) / df['Close'] * 100.0

# %%
df = df[['Close', 'HL_PCT', 'PCT_change', 'Volume']]
print(df.head())
# Out:
#                 Close    HL_PCT  PCT_change     Volume
# Date
# 2010-01-04  15.590930  0.440372   -0.031900   78169752
# 2010-01-05  15.522273  0.617000   -0.508628  120067812
# 2010-01-06  15.130976  2.893498   -2.812129  158988852
# 2010-01-07  14.778734  2.676322   -2.510668  256315428
# 2010-01-08  14.975752  0.204306    1.692573  188783028
