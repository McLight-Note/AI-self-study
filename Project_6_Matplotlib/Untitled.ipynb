# %%
 import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %reload_ext autoreload
# %autoreload 2

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1 ** 2
plt.plot(x_1,y_1)
plt.title('Days Squared Chart')
plt.xlabel('Days')
plt.ylabel('Days Squared')
# Out:
# Text(0, 0.5, 'Days Squared')

# %%
plt.subplot(1,2,1)
plt.plot(x_1, y_1,"r")
plt.title('Days Squared Chart')
plt.xlabel('Days')
plt.ylabel('Days Squared')
plt.subplot(1,2,2)
plt.plot(x_1, y_1,"b")

# %%
figure_1 = plt.figure(figsize=(5,4), dpi=100)
axes_1 = figure_1.add_axes([0.1,0.1,0.9,0.9])
axes_1.set_xlabel('Days')
axes_1.set_ylabel('Days Squared')
axes_1.set_title('Days Squared Chart')
axes_1.plot(x_1,y_1,label='x/(x**2)')
axes_1.plot(y_1,x_1,label='(x**2)/x')
axes_1.legend(loc=0)

axes_2 = figure_1.add_axes([0.45, 0.45, 0.4, 0.3])
axes_2.set_xlabel('Days')
axes_2.set_ylabel('Days Squared')
axes_2.set_title('Days Squared Chart')
axes_2.plot(x_1,y_1, 'g')

arr_1 = np.random.randint(1, 50, 2000)
arr_2 = np.random.randint(1, 50, 2000)
arr_3 = arr_1 + arr_2

axes_1.hist(arr_3, density=False, color='magenta', orientation='vertical', bins=100, histtype='step')
axes_2.hist(arr_3, density=False, color='magenta', orientation='vertical', bins=100, histtype='step')

axes_2.text(0,40,"Message")
# Out:
# Text(0, 40, 'Message')

# %%
import numpy as np
import matplotlib.pyplot as plt

x_1 = np.linspace(0, 10, 100)
y_1 = x_1 ** 2

fig_2, axes_2 = plt.subplots(figsize=(8, 4), nrows=1, ncols=4)
plt.tight_layout()

axes_2[0].set_title('Plot 1')
axes_2[0].set_xlabel('X')
axes_2[0].set_ylabel('X Squared')
axes_2[0].plot(x_1, y_1)
axes_2[0].plot(y_1, x_1)

axes_2[1].set_title('Plot 2')
axes_2[1].set_xlabel('X')
axes_2[1].set_ylabel('X Squared')
axes_2[1].plot(x_1, y_1, 'g')

axes_2[2].set_title('Plot 3')
axes_2[2].set_xlabel('X')
axes_2[2].set_ylabel('X Squared')
axes_2[2].plot(x_1, y_1, 'r')

axes_2[3].set_title('Plot 4')
axes_2[3].set_xlabel('X')
axes_2[3].set_ylabel('X Squared')
axes_2[3].plot(x_1, y_1, 'm')

arr_1 = np.random.randint(1, 6, 2000)
arr_2 = np.random.randint(1, 6, 2000)
arr_3 = arr_1 + arr_2

for ax in axes_2:
    ax.hist(arr_3, bins=7, density=False, stacked=True, histtype='step', color='orange')

plt.show()

# %%
fig_3 = plt.figure(figsize=(6,4))
axes_3 = fig_3.add_axes([0,0,1,1])

# This is some styling options
axes_3.plot(x_1,y_1, color='navy', alpha=.75, lw=5, ls='-.', marker='o', markersize=10, markerfacecolor='y',
            markeredgecolor='r', markeredgewidth=3)

# This is to zoom in
axes_3.set_xlim(0,3)
axes_3.set_ylim(0,8)

# This is to put the backgound grid
axes_3.grid(True, color='0.6', dashes=(5,2,1,2))
axes_3.set_facecolor('#FAEBD7')

arr_1 = np.random.uniform(0,1.5,50)
arr_2 = np.random.uniform(0,1.5,50)
arr_3 = arr_1 + arr_2

plt.hist(arr_3, bins=30, density=False, stacked=True, histtype='step', color='orange')
# Out:
# (array([1., 0., 1., 0., 1., 2., 1., 1., 1., 2., 3., 3., 2., 2., 1., 1., 3.,
#         3., 3., 3., 2., 3., 2., 1., 0., 3., 2., 0., 2., 1.]),
#  array([0.16760091, 0.24768521, 0.32776951, 0.40785381, 0.48793812,
#         0.56802242, 0.64810672, 0.72819102, 0.80827532, 0.88835962,
#         0.96844392, 1.04852822, 1.12861252, 1.20869683, 1.28878113,
#         1.36886543, 1.44894973, 1.52903403, 1.60911833, 1.68920263,
#         1.76928693, 1.84937123, 1.92945554, 2.00953984, 2.08962414,
#         2.16970844, 2.24979274, 2.32987704, 2.40996134, 2.49004564,
#         2.57012994]),
#  [<matplotlib.patches.Polygon at 0x16906be90>])

# %%
fig_3.savefig('3rd_plot.png')

# %%
pkm_df = pd.read_csv('pokemon.csv')
pkm_df = pkm_df.sort_values(by='Name')

pkm_df['HP'] = pkm_df['HP'].replace('None', 0)
np_arr = pkm_df.values
y_2 = pkm_df['HP']
x_2 = range(len(pkm_df))
fig_4 = plt.figure(figsize=(10,4))
axes_4 = fig_4.add_axes([0,0,1,1])
axes_4.set_ylabel('HP')
axes_4.set_xlabel('Number of Pokémon')
axes_4.set_title('Pokémon [HP]')
axes_4.plot(x_2, y_2)

axes_4.annotate('Good HP here!', xy=(113,250), xytext=(150,220), arrowprops=dict(facecolor='black', shrink=0.5))
# plt.bar(x_2,y_2)


# adding the dice roller over it as HW
arr_1 = np.random.randint(1,400,2000)
arr_2 = np.random.randint(1,400,2000)
arr_3 = arr_1 + arr_2

plt.hist(arr_3, bins=11, density=False, stacked=True, histtype='step', color='orange')
# Out:
# (array([ 45., 115., 164., 220., 266., 353., 303., 237., 175.,  92.,  30.]),
#  array([ 14.        ,  84.63636364, 155.27272727, 225.90909091,
#         296.54545455, 367.18181818, 437.81818182, 508.45454545,
#         579.09090909, 649.72727273, 720.36363636, 791.        ]),
#  [<matplotlib.patches.Polygon at 0x16909ba10>])

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1 ** 2
fig_5 = plt.figure(figsize=(8,4), dpi=100)
axes_5 = fig_5.add_axes([0.1,0.1,0.9,0.9])

axes_5.plot(x_1,y_1)
axes_5.set_label('Days Squared Chart')
axes_5.set_xlabel('Days')
axes_5.set_ylabel("Days Squared")
axes_5.set_title('Days Squared Chart')

# Symbols
axes_5.text(1,0.9,
           r'$\alpha \beta \sigma \epsilon \pi \omega \theta \mu \lambda$')
axes_5.text(1,0.7,
           r'$\delta_i \gamma^{ij} \sum_{i=0}^\infty x_i \frac{3}{4}  $')
axes_5.text(1,0.5,
           r'$\frac{10 - \frac{a}{b}}{x} \sin{9} \sin{pi} \sqrt[3]{8} \acute a \div$')
axes_5.text(1,0.3,
           r'$\bar a \hat a \tilde a \vec a \overline {a} \lim_{x \to 2} f(x)=5$')
axes_5.text(1,0.1,
           r'$\geq \leq \neq$')

axes_5.set_ylim(0,1)
axes_5.set_xlim(0,13)

arr_1 = np.random.randint(1,7,7000)
arr_2 = np.random.randint(1,7,7000)
arr_3 = arr_1 + arr_2

plt.hist(arr_3, bins=11, density=True, stacked=True, histtype='step', color='orange')
# Out:
# (array([0.02828571, 0.06411429, 0.09114286, 0.12225714, 0.15368571,
#         0.18181429, 0.15101429, 0.11848571, 0.09098571, 0.06238571,
#         0.03582857]),
#  array([ 2.        ,  2.90909091,  3.81818182,  4.72727273,  5.63636364,
#          6.54545455,  7.45454545,  8.36363636,  9.27272727, 10.18181818,
#         11.09090909, 12.        ]),
#  [<matplotlib.patches.Polygon at 0x1691cd850>])

# %%
arr_1 = np.random.randint(1,7,5000)
arr_2 = np.random.randint(1,7,5000)
arr_3 = arr_1 + arr_2

plt.hist(arr_3, bins=21
         , density=True, stacked=True, histtype='step', color='orange') # cumulative=True orientation='horizontal'
# Out:
# (array([0.05712, 0.     , 0.11172, 0.     , 0.17136, 0.     , 0.21756,
#         0.     , 0.29652, 0.     , 0.3549 , 0.     , 0.29484, 0.     ,
#         0.23604, 0.     , 0.18354, 0.     , 0.11466, 0.     , 0.06174]),
#  array([ 2.        ,  2.47619048,  2.95238095,  3.42857143,  3.9047619 ,
#          4.38095238,  4.85714286,  5.33333333,  5.80952381,  6.28571429,
#          6.76190476,  7.23809524,  7.71428571,  8.19047619,  8.66666667,
#          9.14285714,  9.61904762, 10.0952381 , 10.57142857, 11.04761905,
#         11.52380952, 12.        ]),
#  [<matplotlib.patches.Polygon at 0x16931bc50>])

# %%
# Bar charts
x = ['Nuclear', 'Hydro', 'Coal', 'Gas','Solar','Wind','Other']
per_1 = [71, 10, 3, 7, 2, 4, 3]
variance=[8,3,1,3,1,2,1]
# plt.bar(x, per_1, yerr=variance, color='purple')   # if plt.barh - horizontal bar chart

m_eng=[76,85,86,88,93]
f_eng=[24,15,14,12,7]

spc = np.arange(5)
'''
plt.bar(spc, m_eng, width=0.45, label='Male', edgecolor='k')
plt.bar(spc + 0.45, f_eng, width=0.45, label='Female', edgecolor='k')
plt.xticks(spc + 0.45 / 2, ('Aero', 'Chemical', 'Civil', 'Elec', 'Mech'))
'''
t_type = ['Kind', 'Elem', 'Sec', 'Spec']
m_teach = np.array([2, 20, 44, 14])
f_teach = np.array([98, 80, 56, 86])
ind = np.arange(len(t_type))

plt.xticks(ind, t_type)
plt.xlabel('School Type')
plt.ylabel('Number of Teachers')
plt.title('Number of Male and Female Teachers by School Type')

plt.bar(ind, m_teach, width=0.45, label='Male', bottom=f_teach)
plt.bar(ind, f_teach, width=0.45, label='Female')
plt.legend(loc='lower right')

# %%
import random

fig_6 = plt.figure(figsize= (8,5) ,dpi=100)
axes_6 = fig_6. add_axes ([0.1,0.1,0.9,0.91])

# Create a pie chart of the number of Pokemon by type
types = [ 'Water', 'Ground', 'Normal', 'Flying', 'Grass', 'Psychic', 'Bug', 'Fire', 'Poison', 'Rock',
          'Ghost', 'Fighting', 'Dark', 'Steel', 'Electric', 'Dragon', 'Fairy', 'Ice']
poke_num = [133, 109, 101, 98, 85, 77, 68, 66, 65, 60, 57, 54, 53, 51, 50, 50, 46, 40]
colors = []
for i in range(18):
    rgb = random.uniform(0,.5), random.uniform(0,.5), random.uniform(0,.5)
    colors.append(rgb)

explode = [0] * 18
explode[0] = 0.2
wedges, texts, autotexts = plt.pie(poke_num, explode=explode, labels=types, colors=colors, autopct='%1.0f%%',
                                    shadow=True, startangle=140, textprops=dict(color='w'))
plt.legend(wedges, types, loc='right', bbox_to_anchor=(1, 0, 0.5, 1))

# %%
goog_data = pd.read_csv('data_1.csv')
goog_data_np = goog_data.to_numpy()
goog_cp = goog_data_np[:,4]
holidays = [datetime.datetime(2025, 3, 8), datetime.datetime(2025, 6, 25)]
date_arr = pd.bdate_range(start='2025-03-05', end='2025-08-07',
                          freq='C', holidays=holidays)
date_arr_np = date_arr.to_numpy()
fig_7 = plt.figure(figsize=(8, 5))
axes_7 = fig_7.add_axes([0.1, 0.1, 0.9, 0.9])
plt.plot(date_arr_np, goog_cp[:len(date_arr_np)])
plt.xlabel('Date')
plt.ylabel('Close Price (GOOG)')
plt.title('GOOG Close Price Over Time')
# Out:
# Text(0.5, 1.0, 'GOOG Close Price Over Time')

# %%
goog_data['Open'] = pd.Series([round(val,2) for val in goog_data['Open']],index=goog_data.index)
goog_data['High'] = pd.Series([round(val,2) for val in goog_data['High']],index=goog_data.index)
goog_data['Low'] = pd.Series([round(val,2) for val in goog_data['Low']],index=goog_data.index)
goog_data['Close'] = pd.Series([round(val,2) for val in goog_data['Close']],index=goog_data.index)
goog_data['Adj Close'] = pd.Series([round(val,2) for val in goog_data['Adj Close']],index=goog_data.index)

stk_data = goog_data[-5:]
col_head = ('Date', 'Open','High', 'Low', 'Close','Adj Close', 'Volume')
stk_data_np = stk_data.to_numpy()
plt.figure(linewidth=2, tight_layout={'pad':.5}, figsize=(5,3))

axes_9 = plt.gca()
axes_9.get_xaxis().set_visible(False)
axes_9.get_yaxis().set_visible(False)
plt.box(on=None)

ccolors = plt.cm.Blues(np.full(len(col_head), 0.2))

the_table = plt.table(cellText = stk_data_np, loc='center', colLabels=col_head,
                     colColours=ccolors)
the_table.set_fontsize(14)
the_table.scale(3,2.5)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   func(*args, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data_goog = pd.read_csv('data_2.csv')
data_goog_np = data_goog.to_numpy()

goog_hp = data_goog_np[:, 2]
goog_lp = data_goog_np[:, 3]
holidays_2 = [datetime.datetime(2025, 10, 7), datetime.datetime(2024, 10, 14)]

# Create a business date range (weekdays excluding holidays)
arr_date = pd.bdate_range(start='2024-10-25', end='2025-10-06',
                          freq='C', holidays=holidays_2)
arr_date_np = arr_date.to_numpy()
fig_8 = plt.figure(figsize=(8, 4))
axes_8 = fig_8.add_axes([0.1, 0.1, 0.85, 0.85])
plt.plot(arr_date_np, goog_hp[:len(arr_date_np)])
plt.plot(arr_date_np, goog_lp[:len(arr_date_np)], 'r')

plt.xlabel('Date')
plt.ylabel('High Price (GOOG)')
plt.title('GOOG High Price Over Time')
# Out:
# Text(0.5, 1.0, 'GOOG High Price Over Time')

# %%
data_goog['Open'] = pd.Series([round(val, 2) for val in data_goog['Open']], index=data_goog.index)
data_goog['High'] = pd.Series([round(val, 2) for val in data_goog['High']], index=data_goog.index)
data_goog['Low'] = pd.Series([round(val, 2) for val in data_goog['Low']], index=data_goog.index)
data_goog['Close'] = pd.Series([round(val, 2) for val in data_goog['Close']], index=data_goog.index)
data_goog['Adj Close'] = pd.Series([round(val, 2) for val in data_goog['Adj Close']], index=data_goog.index)

data_stk = data_goog[-5:]
head_col = ('Date', 'Open','High', 'Low', 'Close','Adj Close', 'Volume')
data_stk_np = data_stk.to_numpy()
plt.figure(linewidth=2, tight_layout={'pad':.5}, figsize=(5,3))

axes_10 = plt.gca()
axes_10.get_xaxis().set_visible(False)
axes_10.get_yaxis().set_visible(False)
plt.box(on=None)

cccolors = plt.cm.Blues(np.full(len(head_col), 0.2))

table_2 = plt.table(cellText = data_stk_np, loc='center', colLabels=head_col,
                     colColours=cccolors)
table_2.set_fontsize(14)
table_2.scale(3,2.5)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   func(*args, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 20 countries
countries = np.array(['USA', 'Korea', 'Japan', 'Germany', 'France', 'UK', 'Italy', 'Spain', 'Canada', 'Brazil',
    'India', 'Russia', 'Mexico', 'Indonesia', 'Turkey', 'Australia', 'South Africa', 'Argentina', 'Saudi Arabia', 'Sweden'])

# Death rates per 100,000 (random realistic values)
death_rates = np.array([320, 90, 65, 110, 130, 140, 150, 145, 100, 290,
                        180, 210, 250, 160, 170, 50, 190, 220, 80, 115])

# Daily tests (in thousands)
tests = np.array([950, 520, 480, 600, 580, 550, 500, 490, 560, 420,
                  400, 410, 380, 390, 370, 340, 360, 350, 330, 320])

# Daily confirmed cases (in thousands)
confirmed_cases = np.array([80242, 15124, 2321, 25135, 36323, 28623, 32632, 26231, 22585, 74465,
                            62685, 63560, 53545, 55780, 58352, 13422, 47530, 46345, 12348, 24564])

cc_arr_sm = confirmed_cases / 100
color_arr = np.random.rand(20)

plt.title('Death Rate per 100k vs. Confirmed Cases')
plt.xlabel('Death Rate per 100k')
plt.ylabel('Confirmed Cases')
plt.scatter(death_rates, tests, s=cc_arr_sm, c=color_arr, alpha=0.5)

# %%
from mpl_toolkits import mplot3d

fig_11 = plt.figure(figsize=(8,5), dpi=100)
axes_11 = fig_11.add_axes([0.1,0.1,0.9,0.9], projection= '3d')

z_3 = 15 * np.random.random(100)
x_3 = np.sin(z_3) * np.random.randn(100)
y_3 = np.cos(z_3) * np.random.randn(100)

# axes_11.scatter3D(x_3, y_3, z_3, c=z_3, cmap='Blues')

def get_z(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

x_4 = np.linspace(-6,6,30)
y_4 = np.linspace(-6,6,30)

x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = get_z(x_4, y_4)

axes_11.view_init(45,55)

# axes_11.contour3D(x_4, y_4, z_4, 100, cmap='Blues')

axes_11.set_xlabel('x')
axes_11.set_ylabel('y')
axes_11.set_zlabel('z')

# axes_11.plot_wireframe(x_4, y_4, z_4, color='blue')

axes_11.plot_surface(x_4, y_4, z_4, rstride=1, cstride=1, cmap='Blues')
