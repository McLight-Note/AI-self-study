# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
# Scatter Plot
x_data = np.random.random(1000) * 100
y_data = np.random.random(1000) * 100

plt.scatter(x_data, y_data, c='red', marker='*', s=150, alpha=0.3)
# s      - size
# alpha  - opacity if there are a lot of dots
# marker - how the dots should be
# c      - colors, you can use hex colors '#000, #00f'

# %%
# Line chart
years = [2006 + x for x in range(20)]
weights = [80, 83, 84, 85, 86, 82, 81, 79, 80, 83, 82, 84, 85, 86, 88, 90, 95, 100, 102, 104]
plt.plot(years, weights, c='g', lw=3, linestyle='--')

# lw        - linewidth
# linestyle - how we define the line

# %%
# Line chart
years = [2006 + x for x in range(20)]
weights = [80, 83, 84, 85, 86, 82, 81, 79, 80, 83, 82, 84, 85, 86, 88, 90, 95, 100, 102, 104]
plt.plot(years, weights, 'b--', lw=3)

# 'r--' - we can also use it like this for 'red' + '--'
# 'b--' - we can also use it like this for 'blue' + '--'

# %%
# Bar chart

x = ['c++', 'c#', 'Python', 'Java', 'Go']
y = [20,50,140,1, 45]

plt.bar(x,y, color='r', align='edge', width=0.5, edgecolor='green', lw=6)

# align     - to define the lower text
# width     - to define the width of the bars
# edgecolor - is the color of the edge of the bars
# lw        - linewidth of the edges of the bars
# Out:
# <BarContainer object of 5 artists>

# %%
# Histogram

ages = np.random.normal(20, 1.5, 1000)
plt.hist(ages, bins=20, cumulative=True)

# np.random.normal                      - is a normal distribution for the random numbers in numpy
# bins                                  - how many boxes you want to see
# bins=[ages.min(), 18, 21, ages.max()] - you can pass a formula to get the specified bin
# cumulative=True                       - for acsending order
# Out:
# (array([   2.,    5.,   14.,   33.,   54.,   86.,  161.,  253.,  363.,
#          492.,  623.,  718.,  823.,  891.,  949.,  977.,  990.,  998.,
#          999., 1000.]),
#  array([15.11145552, 15.59480563, 16.07815573, 16.56150584, 17.04485594,
#         17.52820605, 18.01155615, 18.49490625, 18.97825636, 19.46160646,
#         19.94495657, 20.42830667, 20.91165678, 21.39500688, 21.87835698,
#         22.36170709, 22.84505719, 23.3284073 , 23.8117574 , 24.29510751,
#         24.77845761]),
#  <BarContainer object of 20 artists>)

# %%
langs = ['Python', 'C++', 'Java', 'Go', 'C#']
votes = [50, 24, 14, 6, 17]

explodes = [0,0,0,0.2,0]

plt.pie(votes, labels=langs, explode=explodes, autopct='%.2f%%', pctdistance=1.3, startangle=90)

# explode=explodes[n] - taking some parts of the pie chart out of it, n=[list]
# autopct=''          - to mean the percentile of the pie chart blocks
# pctdistance=1.3     - distance from the center of the chart
# startangle=90       - starting angle of the original pie chart
# Out:
# ([<matplotlib.patches.Wedge at 0x1441d2350>,
#   <matplotlib.patches.Wedge at 0x14427a190>,
#   <matplotlib.patches.Wedge at 0x14427b750>,
#   <matplotlib.patches.Wedge at 0x14427af90>,
#   <matplotlib.patches.Wedge at 0x144296590>],
#  [Text(-1.086699599490348, 0.17054026054723181, 'Python'),
#   Text(0.39565761775935304, -1.0263795835406089, 'C++'),
#   Text(1.0910904828506338, -0.13971956997060678, 'Java'),
#   Text(1.176901032282621, 0.5521810936749839, 'Go'),
#   Text(0.509073726682436, 0.9751122708702094, 'C#')],
#  [Text(-1.2842813448522292, 0.2015475806467285, '45.05%'),
#   Text(0.46759536644287175, -1.212994053275265, '21.62%'),
#   Text(1.289470570641658, -0.16512312814708072, '12.61%'),
#   Text(1.3579627295568704, 0.637132031163443, '5.41%'),
#   Text(0.6016325860792425, 1.1524054110284292, '15.32%')])

# %%
heights = np.random.normal(172,8,300)
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1442cb550>,
#   <matplotlib.lines.Line2D at 0x1442cbf90>],
#  'caps': [<matplotlib.lines.Line2D at 0x1442dc9d0>,
#   <matplotlib.lines.Line2D at 0x1442dd390>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1442cae10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1442ddd90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1442de650>],
#  'means': []}

# %%
first = np.linspace(0,10,25)
second = np.linspace(10,200,25)
third = np.linspace(200, 210, 25)
fourth = np.linspace(210, 230, 25)

data = np.concatenate((first, second, third, fourth))
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1443276d0>,
#   <matplotlib.lines.Line2D at 0x144327f50>],
#  'caps': [<matplotlib.lines.Line2D at 0x14432c890>,
#   <matplotlib.lines.Line2D at 0x14432d210>],
#  'boxes': [<matplotlib.lines.Line2D at 0x144326d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x14432dbd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14432e550>],
#  'means': []}

# %%
years = [2014,2015,2016,2017,2018,2019,2020,2021]
income = [55,56,62,61,72,72,73,75]
income_ticks = list(range(50,81,2))

plt.title('Income of John (in USD)', fontsize=15)
'''fontname="_____"'''
plt.xlabel('Year')
plt.ylabel('Yearly income in USD')
plt.yticks(income_ticks, [f"${x}k" for x in income_ticks])
plt.plot(years, income)

# %%
stock_a = [100, 102, 99, 101, 101, 100, 102]
stock_b = [90, 95, 102, 104, 105, 103, 109]
stock_c = [110, 115, 100, 105, 100, 98, 95]

plt.plot(stock_a, label='Company1')
plt.plot(stock_b, label='Company2')
plt.plot(stock_c, label='Company3')
plt.legend(loc='lower center')

# %%
style.use('Solarize_Light2')

votes = [10, 2, 5, 16, 22]
people = ['a', 'b', 'c', 'd', 'e']

plt.pie(votes, labels=None)
plt.legend(labels=people)

# style.use('Solarize_Light2') - how the styling is given

# %%
x1, y1 = np.random.random(100), np.random.random(100)
x2, y2 = np.arange(100), np.random.random(100)

plt.figure(1)
plt.scatter(x1, y1)

plt.figure(2)
plt.plot(x2, y2)

# %%
x = np.arange(100)

fig, axs = plt.subplots(2,2)

axs[0,0].plot(x, np.sin(x))
axs[0,0].set_title('Sine Wave')

axs[0,1].plot(x, np.cos(x))
axs[0,1].set_title('Cosine Wave')

axs[1,0].plot(x, np.random.random(100))
axs[1,0].set_title('Random Function')

axs[1,1].plot(x, np.log(x))
axs[1,1].set_title('Log Function')
axs[1,1].set_xlabel('Test')

fig.suptitle('Four Plots')

plt.tight_layout()

plt.savefig('fourplot.png', dpi=300,
           transparent=False, bbox_inches='tight')

# plt.subplots(2,2)          - creating 2 by 2 grid with plots
# fig.suptitle('Four Plots') - super title setting
# plt.tight_layout()         - to tighten the layout to throw away repeating numbers
# Out:
# /var/folders/0s/s2qqdkfs7_b9yv8pvrv2djp00000gn/T/ipykernel_20350/4257193106.py:14: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x, np.log(x))

# %%
# 3D Plots

ax = plt.axes(projection='3d')

x = np.random.random(100)
y = np.random.random(100)
z = np.random.random(100)

ax.scatter(x, y, z)
ax.set_title('3D Plot')
ax.set_xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %%
# 3D Plots

ax = plt.axes(projection='3d')

x = np.arange(0,50,0.1)
y = np.arange(0,50,0.1)
z = np.cos(x+y)


ax.plot(x, y, z)
ax.set_title('3D Plot')
ax.set_xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %%
# 3D Plots

ax = plt.axes(projection='3d')

x = np.arange(-5,5,0.1)
y = np.arange(-5,5,0.1)

X, Y = np.meshgrid(x,y)
Z = np.sin(X) * np.cos(Y)



ax.plot_surface(X, Y, Z, cmap='Spectral')
ax.set_title('3D Plot')
ax.set_xlabel('X')
ax.view_init(azim=0, elev=90)

# %%
import random

heads_tails = [0, 0]

'''
for _ in range(100000):
    heads_tails[random.randint(0,1)] += 1
    plt.bar(['Heads', 'Tails'], heads_tails, color=['red', 'blue'])
    plt.pause(0.001)
'''
